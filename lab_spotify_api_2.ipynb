# %% [markdown]
# 1. Create a function to search a given **single** song in the Spotify API: **search_song(title, artist, limit)**.
#
# First importing the necessary libraries.

# %%
# Import functionality from other modules

import sys 
from config import *

# %%
import pandas as pd
import numpy as np

import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Initialize SpotiPy with user credentias #

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
# Read both files

not_hot_songs = pd.read_csv('not_hot_songs.csv')
hot_songs = pd.read_csv('hot_songs.csv')

# %%
# Drop Unnamed:0 columns

hot_songs.drop(columns='Unnamed: 0', inplace=True)
not_hot_songs.drop(columns='Unnamed: 0', inplace=True)

# %%
display(not_hot_songs)
display(hot_songs)
# Out:
#              artist                     title
# 0             Queen         Bohemian Rhapsody
# 1        Danny Vera            Roller Coaster
# 2            Eagles          Hotel California
# 3        Billy Joel                 Piano Man
# 4          Coldplay                   Fix You
# ...             ...                       ...
# 1989  Stevie Wonder  Master Blaster (Jammin')
# 1990     Neil Young                   Harvest
# 1991      Radiohead              High And Dry
# 1992   Caro Emerald         A Night Like This
# 1993     Don Henley           New York Minute
#
# [1994 rows x 2 columns]
#                                 title                                 artists
# 0   Rockin' Around The Christmas Tree                              Brenda Lee
# 1     All I Want For Christmas Is You                            Mariah Carey
# 2                    Jingle Bell Rock                             Bobby Helms
# 3                      Last Christmas                                   Wham!
# 4             A Holly Jolly Christmas                               Burl Ives
# ..                                ...                                     ...
# 95                 El Amor de Su Vida            Grupo Frontera & Grupo Firme
# 96               Standing Next To You                               Jung Kook
# 97                     Man Made A Bar     Morgan Wallen Featuring Eric Church
# 98                           Que Onda  Calle 24 x Chino Pacas x Fuerza Regida
# 99                       Great Gatsby                                Rod Wave
#
# [100 rows x 2 columns]

# %%
# Rename column "artists" from not_hot_songs dataframe to "artist"
hot_songs.rename(columns={'artists':'artist'}, inplace=True)
display(hot_songs)
# Out:
#                                 title                                  artist
# 0   Rockin' Around The Christmas Tree                              Brenda Lee
# 1     All I Want For Christmas Is You                            Mariah Carey
# 2                    Jingle Bell Rock                             Bobby Helms
# 3                      Last Christmas                                   Wham!
# 4             A Holly Jolly Christmas                               Burl Ives
# ..                                ...                                     ...
# 95                 El Amor de Su Vida            Grupo Frontera & Grupo Firme
# 96               Standing Next To You                               Jung Kook
# 97                     Man Made A Bar     Morgan Wallen Featuring Eric Church
# 98                           Que Onda  Calle 24 x Chino Pacas x Fuerza Regida
# 99                       Great Gatsby                                Rod Wave
#
# [100 rows x 2 columns]

# %%
# We will start working on the hot_songs dataframe first

hot_songs.head(5)
# Out:
#                                title        artist
# 0  Rockin' Around The Christmas Tree    Brenda Lee
# 1    All I Want For Christmas Is You  Mariah Carey
# 2                   Jingle Bell Rock   Bobby Helms
# 3                     Last Christmas         Wham!
# 4            A Holly Jolly Christmas     Burl Ives

# %%
# Create the get_song_ids function

def get_song_ids(df: pd.DataFrame):
    """
    Get the ID of the songs
    """
    import time
    
    list_of_ids = []
    
    # First, we are creating chunks:
    chunk_size = 50
    
    for start in range(0, len(df), chunk_size):
        chunk = df[start:start+chunk_size]
        
        for index, row in chunk.iterrows():
            try:
                #search_song = sp.search(q="tracks:"+df['title'][s]+" artist:"+df['artist'][s],limit=1)
                search_song = sp.search(q=row['title'], limit=1)
                song_id = search_song['tracks']['items'][0]['id']
                list_of_ids.append(song_id)
            
            except:
                print("Song not found!")
                list_of_ids.append("")
                
        print("Sleeping a bit before getting the next ids")
        time.sleep(10)
        
    return list_of_ids

# %%
# Execute the function on the hot_songs dataframe and create a list with all the ids

hot_song_id_list = get_song_ids(hot_songs)
# Out:
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids

# %%
# Display the list of ids

hot_song_id_list
# Out:
# ['2EjXfH91m7f8HiJN1yQg97',
#  '0bYg9bo50gSsH3LtXe2SQn',
#  '7vQbuQcyTflfCIOu3Uzzya',
#  '2FRnf9qhLbvw8fu4IBXx78',
#  '77khP2fIVhSW23NwxrRluh',
#  '5hslUAKq9I9CG2bAulFkHN',
#  '2uFaJJtFpPDc5Pa95XzTvg',
#  '0oPdaY4dXtc3ZsaG17V972',
#  '4xhsWYTOGcal8zt0J161CU',
#  '5ASM6Qjiav2xPe7gRkQMsQ',
#  '0lizgQ7Qw35od7CYaoMBZb',
#  '7uhWhGcR3kn9czLKlbO46q',
#  '3YZE5qDV7u1ZD1gZc47ZeR',
#  '72Z28IsvEVLjSWdUKEQgZ0',
#  '46pF1zFimM582ss1PrMy68',
#  '4KV9bM7a1KDc7b7OakFZic',
#  '0rHToGels2lt8Y0mCYoF90',
#  '3QiAAp20rPC3dcAtKtMaqQ',
#  '1BxfuPKGuaTgP7aM0Bbdwr',
#  '1vZKP9XURuqMp1SpXGnoyb',
#  '7n7VsX3sv66znBwA8b5uhp',
#  '2pnPe4pJtq7689i5ydzvJJ',
#  '5a1iz510sv2W9Dt1MvFd5R',
#  '3rUGC1vUpkDG9CZFHMur1t',
#  '75dfH68JDisE8dDaD4KlVY',
#  '1SV1fxF65n9NhRHp3KlBuu',
#  '5a1iz510sv2W9Dt1MvFd5R',
#  '3QIoEi8Enr9uHffwInGIsC',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '6s2wpWPFPAgKg2LXxi1Oee',
#  '4KULAymBBJcPRpk1yO4dOG',
#  '5aIVCx5tnk0ntmdiinnYvw',
#  '5xQskDSiHQeoebxoprn3HL',
#  '38xhBO2AKrJnjdjVnhJES6',
#  '7dJYggqjKo71KI9sLzqCs8',
#  '59uQI0PADDKeE6UZDTJEe8',
#  '7xapw9Oy21WpfEcib2ErSA',
#  '3sDdyBHQ60Cs1opmIyRvhp',
#  '2L0KL66EuxLHiJZX7Uj6I3',
#  '1OjmlSFuzYflWjSMTCyTJv',
#  '2FPfeYlrbSBR8PwCU0zaqq',
#  '27RYrbL6S02LNVhDWVl38b',
#  '15sxLiiChE5dCW3Y756oas',
#  '0PAcdVzhPO4gq1Iym9ESnK',
#  '1dtIaSlyrLI04sqYa8nLyN',
#  '4v9WbaxW8HdjqfUiWYWsII',
#  '1Lo0QY9cvc8sUB2vnIOxDT',
#  '6usohdchdzW9oML7VC4Uhk',
#  '1Iq8oo9XkmmvCQiGOfORiz',
#  '0ZamzoOYLzRxE3WuOb5J3r',
#  '0cVyQfDyRnMJ0V3rjjdlU3',
#  '1yeB8MUNeLo9Ek1UEpsyz6',
#  '1a73gcEg6h6Re6hHXoVltJ',
#  '0mflMxspEfB0VbI1kyLiAv',
#  '4RvWPyQ5RL0ao9LPZeSouE',
#  '7MSWxMumjz6lHj7oRApNbg',
#  '7aqfrAY2p9BUSiupwk3svU',
#  '41WQUSINanQHfhfKpFDsms',
#  '4OMJGnvZfDvsePyCwRGO7X',
#  '0J1YRLYhTG1MBosjidD7OI',
#  '5ya0TmUQw2wHMkq36rPsnd',
#  '0R6NfOiLzLj4O5VbYSJAjf',
#  '2gT2iF1YK5r54A2PDEXVv8',
#  '1o8Z7GD1CeOaVBEyuzu4HO',
#  '3vkCueOmm7xQDoJ17W1Pm3',
#  '0HD8mbiPjp3o94X3EaZp0o',
#  '1udwFobQ1JoOdWPQrp2b6u',
#  '4MjDJD8cW7iVeWInc2Bdyj',
#  '5mjYQaktjmjcMKcUIcqz4s',
#  '5Se32hEA9raeboZerywxka',
#  '2gyxAWHebV7xPYVxqoi86f',
#  '2YSzYUF3jWqb9YP9VXmpjE',
#  '6CvTEtGagmzQvkUzzyKR9k',
#  '2kE2HFBFkJ0VMw3igxYohz',
#  '05WVKTdZhlIMX4qqMLuo0f',
#  '73NzYbpaYvQ7JfpjztFESL',
#  '7hZTywPKMdVjJzwdWu11BK',
#  '4KV9bM7a1KDc7b7OakFZic',
#  '5XVdHRf4CAJ2Jm0uMIy5qY',
#  '0eBFgRxyVSeuT4iyrbukdn',
#  '3XB5uhhlYSnkxpSihkNQwh',
#  '3CWq0pAKKTWb0K4yiglDc4',
#  '1xWkeSPhf3bZqHY7Ncz8vp',
#  '6UoKX6uLJwhsnyTp5k5StP',
#  '6uTPdRrEDeH8Fyg5L5qmeU',
#  '09hVlIVHtEE1nLUv6YGZiW',
#  '1GjQLnGAfpv3rWW1K9Ll8p',
#  '6fNCrsrdIcgVd2aZZ0nnz4',
#  '4I4G0LD277PWvfblYtSf91',
#  '2ljUUoqlnRUGGa7bmpvevC',
#  '7rr3gguU3TcVnLZD9VzASE',
#  '4qmG24ebshLXtKu9HIShBP',
#  '4pCbJC43j3gSqG6Fen6upD',
#  '2Zo1PcszsT9WQ0ANntJbID',
#  '56xHMIfQPoe0prrSi3BGhf',
#  '0O3U5iwTbiXCREMkvotJuN',
#  '2KslE17cAJNHTsI2MI0jb2',
#  '73zawW1ttszLRgT9By826D',
#  '6uIIdjYTxxpWOyWuVXrKQO',
#  '4M68xjcc42oxyphhzpOWXS']

# %% [markdown]
# 2. Once the desired song is located, **the function should return the href/id/uri of the song to the code** (not to the user) to get the audio features.
#
# Create a function **get_audio_features(list_of_song_ids)** to obtain the audio features of a given list of songs (the content of list_of_songs can be the href/id/uri or a list with a single song IDs).

# %%
# Create a function to get the songs audio features

def get_audio_features(list_of_song_ids: list):
    """
    Using the song IDs to get the audio features out of the Spotify Database.
    """
    
    import time 
    
    feature_list = []
    feature_df = pd.DataFrame()
    # define a chunk size
    chunk_size = 50
    
    for start in range(0, len(list_of_song_ids), chunk_size):
        #for start in range(0,100,50) -> chunk_size is the increment. second loop will start from chunk_size
        try:
            features = sp.audio_features(tracks=list_of_song_ids[start:start+chunk_size])
            #features = sp.audio_features(tracks=[1,2,3,4,…50])
            
            for f in features:
                df_temp = pd.DataFrame([f])
                feature_df = pd.concat([feature_df, df_temp], ignore_index=True)
        
        except:
            #print(f'Error processing tracks ({i} : {i+chunk_size}) -> {err}')
            print("Error processing tracks")
    print("Sleeping a bit before getting the next features")
    time.sleep(10)
    
    return feature_df

# %%
# Execute the function on the hot_songs dataframe and create a list with all the ids

hot_song_feature_df = get_audio_features(hot_song_id_list)
# Out:
# Sleeping a bit before getting the next features

# %%
# Review dataframe created

hot_song_feature_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.589   0.472    8    -8.749     1       0.0502         0.614
# 1         0.336   0.627    7    -7.463     1       0.0384         0.164
# 2         0.754   0.424    2    -8.463     1       0.0363         0.643
# 3         0.735   0.478    2   -12.472     1       0.0293         0.189
# 4         0.683   0.375    0   -13.056     1       0.0303         0.579
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.5050    0.898   67.196  audio_features
# 1          0.000000    0.0708    0.350  150.273  audio_features
# 2          0.000000    0.0652    0.806  119.705  audio_features
# 3          0.000002    0.3550    0.947  107.682  audio_features
# 4          0.000000    0.0760    0.888  140.467  audio_features
#
#                        id                                   uri  \
# 0  2EjXfH91m7f8HiJN1yQg97  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 1  0bYg9bo50gSsH3LtXe2SQn  spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 2  7vQbuQcyTflfCIOu3Uzzya  spotify:track:7vQbuQcyTflfCIOu3Uzzya
# 3  2FRnf9qhLbvw8fu4IBXx78  spotify:track:2FRnf9qhLbvw8fu4IBXx78
# 4  77khP2fIVhSW23NwxrRluh  spotify:track:77khP2fIVhSW23NwxrRluh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2EjXfH91m7f8...
# 1  https://api.spotify.com/v1/tracks/0bYg9bo50gSs...
# 2  https://api.spotify.com/v1/tracks/7vQbuQcyTflf...
# 3  https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# 4  https://api.spotify.com/v1/tracks/77khP2fIVhSW...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2EjX...       126267
# 1  https://api.spotify.com/v1/audio-analysis/0bYg...       241107
# 2  https://api.spotify.com/v1/audio-analysis/7vQb...       130973
# 3  https://api.spotify.com/v1/audio-analysis/2FRn...       262960
# 4  https://api.spotify.com/v1/audio-analysis/77kh...       135533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# 3. Once the previous function has been created, create another function **add_audio_features(df, audio_features_df)** to concat a given dataframe with the audio features dataframe and return the extended data frame.

# %%
# Create a function to concatenate the hot_song_feature_df to the hot_songs one

def add_audio_features(df, audio_features_df):
    """
    Concats a given dataframe with the audio features dataframe and return the extended data frame. 
    """
    
    final_df = pd.concat([df, audio_features_df], axis=1)
    
    return final_df

# %%
# Execute the function

final_hot_songs = add_audio_features(hot_songs, hot_song_feature_df)

# %%
# Review concatenated dataframe

final_hot_songs.head()
# Out:
#                                title        artist  danceability  energy  key  \
# 0  Rockin' Around The Christmas Tree    Brenda Lee         0.589   0.472    8
# 1    All I Want For Christmas Is You  Mariah Carey         0.336   0.627    7
# 2                   Jingle Bell Rock   Bobby Helms         0.754   0.424    2
# 3                     Last Christmas         Wham!         0.735   0.478    2
# 4            A Holly Jolly Christmas     Burl Ives         0.683   0.375    0
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -8.749     1       0.0502         0.614          0.000000    0.5050
# 1    -7.463     1       0.0384         0.164          0.000000    0.0708
# 2    -8.463     1       0.0363         0.643          0.000000    0.0652
# 3   -12.472     1       0.0293         0.189          0.000002    0.3550
# 4   -13.056     1       0.0303         0.579          0.000000    0.0760
#
#    valence    tempo            type                      id  \
# 0    0.898   67.196  audio_features  2EjXfH91m7f8HiJN1yQg97
# 1    0.350  150.273  audio_features  0bYg9bo50gSsH3LtXe2SQn
# 2    0.806  119.705  audio_features  7vQbuQcyTflfCIOu3Uzzya
# 3    0.947  107.682  audio_features  2FRnf9qhLbvw8fu4IBXx78
# 4    0.888  140.467  audio_features  77khP2fIVhSW23NwxrRluh
#
#                                     uri  \
# 0  spotify:track:2EjXfH91m7f8HiJN1yQg97
# 1  spotify:track:0bYg9bo50gSsH3LtXe2SQn
# 2  spotify:track:7vQbuQcyTflfCIOu3Uzzya
# 3  spotify:track:2FRnf9qhLbvw8fu4IBXx78
# 4  spotify:track:77khP2fIVhSW23NwxrRluh
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2EjXfH91m7f8...
# 1  https://api.spotify.com/v1/tracks/0bYg9bo50gSs...
# 2  https://api.spotify.com/v1/tracks/7vQbuQcyTflf...
# 3  https://api.spotify.com/v1/tracks/2FRnf9qhLbvw...
# 4  https://api.spotify.com/v1/tracks/77khP2fIVhSW...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2EjX...       126267
# 1  https://api.spotify.com/v1/audio-analysis/0bYg...       241107
# 2  https://api.spotify.com/v1/audio-analysis/7vQb...       130973
# 3  https://api.spotify.com/v1/audio-analysis/2FRn...       262960
# 4  https://api.spotify.com/v1/audio-analysis/77kh...       135533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
# Save final_hot_songs dataframe in .csv file

final_hot_songs.to_csv('final_hot_songs.csv')

# %%
# Let's do the same process but this time for the not_hot_songs dataframe

not_hot_song_id_list = get_song_ids(not_hot_songs)
# Out:
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids
# Sleeping a bit before getting the next ids

# %%
# Display the list of ids - As we have a lot, we would only do a len() of the list
# We have 1994 songs because we removed 6 of them in the previous lab

len(not_hot_song_id_list)
# Out:
# 1994

# %%
# Execute the function get_audio_features() on the not_hot_songs dataframe and create a list with all the ids

not_hot_song_feature_df = get_audio_features(not_hot_song_id_list)
# Out:
# Sleeping a bit before getting the next features

# %%
# Display dataframe

display(not_hot_song_feature_df)
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.397  0.3860    0   -10.405     0       0.0503       0.27100
# 1            0.713  0.8990    7    -3.386     1       0.0584       0.09560
# 2            0.579  0.5080    2    -9.484     1       0.0270       0.00574
# 3            0.331  0.5500    0    -6.483     1       0.0272       0.60500
# 4            0.209  0.4170    3    -8.740     1       0.0338       0.16400
# ...            ...     ...  ...       ...   ...          ...           ...
# 1989         0.877  0.4220   10   -14.933     0       0.0546       0.04000
# 1990         0.641  0.6770    6    -7.948     1       0.2250       0.49100
# 1991         0.419  0.3830    4   -11.782     1       0.0256       0.07240
# 1992         0.773  0.0272    7   -25.118     1       0.0708       0.93800
# 1993         0.551  0.2890    8   -12.214     0       0.0262       0.33400
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1880    0.210  144.242  audio_features
# 1             0.000000    0.3870    0.611  120.027  audio_features
# 2             0.000494    0.0575    0.609  147.125  audio_features
# 3             0.000004    0.1920    0.429  177.734  audio_features
# 4             0.001960    0.1130    0.124  138.178  audio_features
# ...                ...       ...      ...      ...             ...
# 1989          0.000406    0.1820    0.970  131.103  audio_features
# 1990          0.000077    0.1850    0.503   74.986  audio_features
# 1991          0.017600    0.0896    0.350   87.568  audio_features
# 1992          0.862000    0.0967    0.522  107.992  audio_features
# 1993          0.000000    0.0379    0.117  132.133  audio_features
#
#                           id                                   uri  \
# 0     6l8GvAyoUZwWDgF1e4822w  spotify:track:6l8GvAyoUZwWDgF1e4822w
# 1     1fP8o0lIaSIE5jEeblT8df  spotify:track:1fP8o0lIaSIE5jEeblT8df
# 2     40riOy7x9W7GXjyGp4pjAv  spotify:track:40riOy7x9W7GXjyGp4pjAv
# 3     70C4NyhjD5OZUMzvWZ3njJ  spotify:track:70C4NyhjD5OZUMzvWZ3njJ
# 4     7LVHVU3tWfcxj5aiPFEW4Q  spotify:track:7LVHVU3tWfcxj5aiPFEW4Q
# ...                      ...                                   ...
# 1989  5EAgXGJ8Kw5QAfhQkZXYqT  spotify:track:5EAgXGJ8Kw5QAfhQkZXYqT
# 1990  1ejyx2kXWFY6QuYHu7yOyD  spotify:track:1ejyx2kXWFY6QuYHu7yOyD
# 1991  2a1iMaoWQ5MnvLFBDv4qkf  spotify:track:2a1iMaoWQ5MnvLFBDv4qkf
# 1992  7fk9IaVqs4DKkHQvcswJuL  spotify:track:7fk9IaVqs4DKkHQvcswJuL
# 1993  2jxqu3v4AZAhUNvdAbDGet  spotify:track:2jxqu3v4AZAhUNvdAbDGet
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6l8GvAyoUZwW...
# 1     https://api.spotify.com/v1/tracks/1fP8o0lIaSIE...
# 2     https://api.spotify.com/v1/tracks/40riOy7x9W7G...
# 3     https://api.spotify.com/v1/tracks/70C4NyhjD5OZ...
# 4     https://api.spotify.com/v1/tracks/7LVHVU3tWfcx...
# ...                                                 ...
# 1989  https://api.spotify.com/v1/tracks/5EAgXGJ8Kw5Q...
# 1990  https://api.spotify.com/v1/tracks/1ejyx2kXWFY6...
# 1991  https://api.spotify.com/v1/tracks/2a1iMaoWQ5Mn...
# 1992  https://api.spotify.com/v1/tracks/7fk9IaVqs4DK...
# 1993  https://api.spotify.com/v1/tracks/2jxqu3v4AZAh...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6l8G...       355400
# 1     https://api.spotify.com/v1/audio-analysis/1fP8...       179373
# 2     https://api.spotify.com/v1/audio-analysis/40ri...       391376
# 3     https://api.spotify.com/v1/audio-analysis/70C4...       339000
# 4     https://api.spotify.com/v1/audio-analysis/7LVH...       295533
# ...                                                 ...          ...
# 1989  https://api.spotify.com/v1/audio-analysis/5EAg...       307933
# 1990  https://api.spotify.com/v1/audio-analysis/1ejy...       136998
# 1991  https://api.spotify.com/v1/audio-analysis/2a1i...       257480
# 1992  https://api.spotify.com/v1/audio-analysis/7fk9...       112932
# 1993  https://api.spotify.com/v1/audio-analysis/2jxq...       395400
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  3
# 4                  4
# ...              ...
# 1989               4
# 1990               4
# 1991               4
# 1992               4
# 1993               4
#
# [1994 rows x 18 columns]

# %%
# Execute function add_audio_features()

final_not_hot_songs = add_audio_features(not_hot_songs, not_hot_song_feature_df)

# %%
# Review dataframe

final_not_hot_songs.head()
# Out:
#        artist              title  danceability  energy  key  loudness  mode  \
# 0       Queen  Bohemian Rhapsody         0.397   0.386    0   -10.405     0
# 1  Danny Vera     Roller Coaster         0.713   0.899    7    -3.386     1
# 2      Eagles   Hotel California         0.579   0.508    2    -9.484     1
# 3  Billy Joel          Piano Man         0.331   0.550    0    -6.483     1
# 4    Coldplay            Fix You         0.209   0.417    3    -8.740     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0503       0.27100          0.000000    0.1880    0.210  144.242
# 1       0.0584       0.09560          0.000000    0.3870    0.611  120.027
# 2       0.0270       0.00574          0.000494    0.0575    0.609  147.125
# 3       0.0272       0.60500          0.000004    0.1920    0.429  177.734
# 4       0.0338       0.16400          0.001960    0.1130    0.124  138.178
#
#              type                      id  \
# 0  audio_features  6l8GvAyoUZwWDgF1e4822w
# 1  audio_features  1fP8o0lIaSIE5jEeblT8df
# 2  audio_features  40riOy7x9W7GXjyGp4pjAv
# 3  audio_features  70C4NyhjD5OZUMzvWZ3njJ
# 4  audio_features  7LVHVU3tWfcxj5aiPFEW4Q
#
#                                     uri  \
# 0  spotify:track:6l8GvAyoUZwWDgF1e4822w
# 1  spotify:track:1fP8o0lIaSIE5jEeblT8df
# 2  spotify:track:40riOy7x9W7GXjyGp4pjAv
# 3  spotify:track:70C4NyhjD5OZUMzvWZ3njJ
# 4  spotify:track:7LVHVU3tWfcxj5aiPFEW4Q
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6l8GvAyoUZwW...
# 1  https://api.spotify.com/v1/tracks/1fP8o0lIaSIE...
# 2  https://api.spotify.com/v1/tracks/40riOy7x9W7G...
# 3  https://api.spotify.com/v1/tracks/70C4NyhjD5OZ...
# 4  https://api.spotify.com/v1/tracks/7LVHVU3tWfcx...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6l8G...       355400
# 1  https://api.spotify.com/v1/audio-analysis/1fP8...       179373
# 2  https://api.spotify.com/v1/audio-analysis/40ri...       391376
# 3  https://api.spotify.com/v1/audio-analysis/70C4...       339000
# 4  https://api.spotify.com/v1/audio-analysis/7LVH...       295533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               3
# 4               4

# %%
# Save final_not_hot_songs dataframe in .csv file

final_not_hot_songs.to_csv('final_not_hot_songs.csv')
